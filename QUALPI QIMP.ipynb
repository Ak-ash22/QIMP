# %%
import numpy as np
from math import pi
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, transpile, assemble, IBMQ, Aer
from qiskit.tools.jupyter import *
from qiskit.visualization import plot_histogram

# %%
qr1 = QuantumRegister(8,'pv')
qr2 = QuantumRegister(1,'r')
qr3 = QuantumRegister(3,'theta')
qc = QuantumCircuit(qr1,qr2,qr3)
qc.draw()
# Out:
#
#    pv_0:
#
#    pv_1:
#
#    pv_2:
#
#    pv_3:
#
#    pv_4:
#
#    pv_5:
#
#    pv_6:
#
#    pv_7:
#
#       r:
#
# theta_0:
#
# theta_1:
#
# theta_2:

# %%
for k in range(8,12,1):
   qc.h(k)
for j in range(0,8,1):
    qc.i(j)
qc.barrier()
qc.draw('mpl')

# %%
#1st Quadrant

for k in range(8,12,1):
    qc.x(k)
qc.ccx(8,9,0)
qc.ccx(8,9,1)
qc.ccx(9,10,2)
qc.ccx(9,10,3)
qc.ccx(10,11,4)
qc.ccx(10,11,5)
qc.ccx(9,10,6)
qc.ccx(9,10,7)
for j in range(8,12,1):
    qc.x(j)
qc.barrier()

# %%
qc.x(9)
qc.x(10)
qc.x(11)
qc.ccx(8,9,0)
qc.ccx(8,9,1)
qc.ccx(9,10,2)
qc.ccx(9,10,3)
qc.ccx(10,11,4)
qc.ccx(10,11,5)
qc.ccx(9,10,6)
qc.ccx(9,10,7)
qc.x(9)
qc.x(10)
qc.x(11)
qc.barrier()

# %%
qc.x(8)
qc.x(9)
qc.x(10)
qc.ccx(8,9,0)
qc.ccx(8,9,1)
qc.ccx(9,10,2)
qc.ccx(9,10,3)
qc.ccx(10,11,4)
qc.ccx(10,11,5)
qc.ccx(9,10,6)
qc.ccx(9,10,7)
qc.x(8)
qc.x(9)
qc.x(10)
qc.barrier()

# %%
qc.x(9)
qc.x(10)
qc.ccx(8,9,0)
qc.ccx(8,9,1)
qc.ccx(9,10,2)
qc.ccx(9,10,3)
qc.ccx(10,11,4)
qc.ccx(10,11,5)
qc.ccx(9,10,6)
qc.ccx(9,10,7)
qc.x(9)
qc.x(10)
qc.barrier()

# %%
#Quadrant 2

qc.x(8)
qc.x(10)
qc.x(11)
qc.ccx(8,9,4)
qc.ccx(9,10,5)
qc.ccx(10,11,6)
qc.ccx(8,9,7)
qc.x(8)
qc.x(10)
qc.x(11)
qc.barrier()

# %%
qc.x(10)
qc.x(11)
qc.ccx(8,9,4)
qc.ccx(9,10,5)
qc.ccx(10,11,6)
qc.ccx(8,9,7)
qc.x(10)
qc.x(11)
qc.barrier()

# %%
qc.x(8)
qc.x(10)
qc.ccx(8,9,4)
qc.ccx(9,10,5)
qc.ccx(10,11,6)
qc.ccx(8,9,7)
qc.x(8)
qc.x(10)
qc.barrier()

# %%
qc.x(10)
qc.ccx(8,9,4)
qc.ccx(9,10,5)
qc.ccx(10,11,6)
qc.ccx(8,9,7)
qc.x(10)
qc.barrier()

# %%
# Quadrant 3

qc.x(8)
qc.x(9)
qc.x(11)
qc.ccx(8,9,0)
qc.ccx(8,9,1)
qc.ccx(9,10,2)
qc.ccx(9,10,3)
qc.ccx(10,11,4)
qc.ccx(10,11,5)
qc.ccx(8,9,6)
qc.x(8)
qc.x(9)
qc.x(11)
qc.barrier()

# %%
qc.x(9)
qc.x(11)
qc.ccx(8,9,0)
qc.ccx(8,9,1)
qc.ccx(9,10,2)
qc.ccx(9,10,3)
qc.ccx(10,11,4)
qc.ccx(10,11,5)
qc.ccx(8,9,6)
qc.x(9)
qc.x(11)
qc.barrier()

# %%
qc.x(8)
qc.x(9)
qc.ccx(8,9,0)
qc.ccx(8,9,1)
qc.ccx(9,10,2)
qc.ccx(9,10,3)
qc.ccx(10,11,4)
qc.ccx(10,11,5)
qc.ccx(8,9,6)
qc.x(8)
qc.x(9)
qc.barrier()

# %%
qc.x(9)
qc.ccx(8,9,0)
qc.ccx(8,9,1)
qc.ccx(9,10,2)
qc.ccx(9,10,3)
qc.ccx(10,11,4)
qc.ccx(10,11,5)
qc.ccx(8,9,6)
qc.x(9)
qc.barrier()

# %%
# Quadrant 4

qc.x(8)
qc.x(11)
qc.ccx(8,9,4)
qc.ccx(9,10,5)
qc.ccx(10,11,6)
qc.x(8)
qc.x(11)
qc.barrier()

# %%
qc.x(11)
qc.ccx(8,9,4)
qc.ccx(9,10,5)
qc.ccx(10,11,6)
qc.x(11)
qc.barrier()

# %%
qc.x(8)
qc.ccx(8,9,4)
qc.ccx(9,10,5)
qc.ccx(10,11,6)
qc.x(8)
qc.barrier()

# %%
qc.ccx(8,9,4)
qc.ccx(9,10,5)
qc.ccx(10,11,6)

# %%
qc.measure_all()
qc.draw('mpl')

# %%
aer_sim = Aer.get_backend('aer_simulator')
qc_t = transpile(qc,aer_sim)
job = aer_sim.run(qc_t,shots=8900)
result = job.result()
print(result.get_counts())
plot_histogram(result.get_counts())
# Out:
# {'100000000000': 538, '110100000000': 589, '101100000000': 559, '001100000000': 609, '001000000000': 530, '000000000000': 591, '010000000000': 517, '000100000000': 552, '111000000000': 544, '111100000000': 572, '101000000000': 538, '011000000000': 552, '110000000000': 516, '011100000000': 578, '010100000000': 511, '100100000000': 604}
