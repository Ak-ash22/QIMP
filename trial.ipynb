# %%
import numpy as np
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
import qiskit as qk
from qiskit import QuantumCircuit, Aer, IBMQ
from qiskit import transpile, assemble
from qiskit.tools.jupyter import *
from qiskit.visualization import plot_histogram
from qiskit.quantum_info import Statevector
from math import pi

# %%
qr1 = QuantumRegister(2,'pos')
qr2 = QuantumRegister(3,'pv') #pv = pixelvalue
cr = ClassicalRegister(2)
qc = QuantumCircuit(qr1,qr2,cr)
qc.draw('mpl')

# %%
#Setting superposition
qc.h(0)
qc.h(1)
for k in range(2,5,1):
    qc.i(k)
qc.barrier()
qc.draw('mpl')

# %%
theta_r = pi/2
theta_g = pi/2
theta_b = pi/2

# %%
#pixel 1
qc.cry(theta_r,0,2)
qc.cx(0,1)
qc.cry(theta_r,1,2)
qc.cx(0,1)
qc.cry(theta_r,1,2)
qc.barrier()

qc.cry(theta_g,0,3)
qc.cx(0,1)
qc.cry(theta_g,1,3)
qc.cx(0,1)
qc.cry(theta_g,1,3)
qc.barrier()

qc.cry(theta_b,0,4)
qc.cx(0,1)
qc.cry(theta_b,1,4)
qc.cx(0,1)
qc.cry(theta_b,1,4)
qc.barrier()

qc.draw('mpl')

# %%
#pixel 2
qc.x(1)

qc.cry(theta_r,0,2)
qc.cx(0,1)
qc.cry(theta_r,1,2)
qc.cx(0,1)
qc.cry(theta_r,1,2)
qc.barrier()

qc.cry(theta_g,0,3)
qc.cx(0,1)
qc.cry(theta_g,1,3)
qc.cx(0,1)
qc.cry(theta_g,1,3)
qc.barrier()

qc.cry(theta_b,0,4)
qc.cx(0,1)
qc.cry(theta_b,1,4)
qc.cx(0,1)
qc.cry(theta_b,1,4)

qc.barrier()
qc.draw('mpl')

# %%
#pixel 3
qc.x(0)
qc.x(1)

qc.cry(theta_r,0,2)
qc.cx(0,1)
qc.cry(theta_r,1,2)
qc.cx(0,1)
qc.cry(theta_r,1,2)
qc.barrier()

qc.cry(theta_g,0,3)
qc.cx(0,1)
qc.cry(theta_g,1,3)
qc.cx(0,1)
qc.cry(theta_g,1,3)
qc.barrier()

qc.cry(theta_b,0,4)
qc.cx(0,1)
qc.cry(theta_b,1,4)
qc.cx(0,1)
qc.cry(theta_b,1,4)

qc.barrier()
qc.draw('mpl')

# %%
#pixel 4
qc.x(1)

qc.cry(theta_r,0,2)
qc.cx(0,1)
qc.cry(theta_r,1,2)
qc.cx(0,1)
qc.cry(theta_r,1,2)
qc.barrier()

qc.cry(theta_g,0,3)
qc.cx(0,1)
qc.cry(theta_g,1,3)
qc.cx(0,1)
qc.cry(theta_g,1,3)
qc.barrier()

qc.cry(theta_b,0,4)
qc.cx(0,1)
qc.cry(theta_b,1,4)
qc.cx(0,1)
qc.cry(theta_b,1,4)


qc.draw('mpl')

# %%
qc.measure_all()
qc.draw('mpl')

# %%
aer_sim = Aer.get_backend('aer_simulator')
qc_t = transpile(qc,aer_sim)
job = aer_sim.run(qc_t,shots = 8912)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'11110 00': 2197, '11101 00': 2232, '11111 00': 2189, '11100 00': 2294}

# %% [markdown]
# # Trial

# %%
qr9=QuantumRegister(2,'pos')
qr8=QuantumRegister(3,'pv')
cr7=ClassicalRegister(2)
qc1=QuantumCircuit(qr9,qr8,cr7)
qc1.draw('mpl')

# %%
#Setting superposition
qc1.h(0)
qc1.h(1)
for k in range(2,5,1):
    qc1.i(k)
qc1.barrier()
qc1.draw('mpl')

# %%
theta = 0
#pixel 1

qc1.cry(theta,0,2)
qc1.cx(0,1)
qc1.cry(theta,1,2)
qc1.cx(0,1)
qc1.cry(theta,1,2)
qc1.barrier()


qc1.draw('mpl')

# %%
qc1.measure_all()
qc1.draw('mpl')

# %%
aer_sim=Aer.get_backend('aer_simulator')
t_qc=transpile(qc1,aer_sim)
job1=aer_sim.run(t_qc,shots=8912)
result1=job1.result()
counts1=result1.get_counts()
print(counts1)
plot_histogram(counts1)
# Out:
# {'00001 00': 2267, '00011 00': 2165, '00000 00': 2250, '00010 00': 2230}
