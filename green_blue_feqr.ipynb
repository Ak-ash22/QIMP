# %%
import numpy as np
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
import qiskit as qk
from qiskit import QuantumCircuit, Aer, IBMQ
from qiskit import transpile, assemble
from qiskit.tools.jupyter import *
from qiskit.visualization import plot_histogram
from qiskit.quantum_info import Statevector
from math import pi

# %%
qr1 = QuantumRegister(2,'pos')
qr2 = QuantumRegister(3,'pv') #pv = ed pixelvalue
cr = ClassicalRegister(2)
rqc = QuantumCircuit(qr1,qr2,cr)
rqc.draw('mpl')

# %%
rqc.h(0)
rqc.h(1)
rqc.i(2)
rqc.barrier()

# %%
rtheta = pi/2

# %%
#pixel 1
rqc.cry(rtheta,0,2)
rqc.cx(0,1)
rqc.cry(rtheta,1,2)
rqc.cx(0,1)
rqc.cry(rtheta,1,2)
rqc.barrier()

# %%
#pixel 2
rqc.x(1)
rqc.cry(rtheta,0,2)
rqc.cx(0,1)
rqc.cry(rtheta,1,2)
rqc.cx(0,1)
rqc.cry(rtheta,1,2)
rqc.barrier()

# %%
#pixel 3
rqc.x(0)
rqc.x(1)
rqc.cry(rtheta,0,2)
rqc.cx(0,1)
rqc.cry(rtheta,1,2)
rqc.cx(0,1)
rqc.cry(rtheta,1,2)
rqc.barrier()

# %%
#pixel 4
rqc.x(1)
rqc.cry(rtheta,0,2)
rqc.cx(0,1)
rqc.cry(rtheta,1,2)
rqc.cx(0,1)
rqc.cry(rtheta,1,2)

# %%
rqc.measure_all()
rqc.draw('mpl')

# %%
aer_sim = Aer.get_backend('aer_simulator')
rqc_t = transpile(rqc,aer_sim)
rjob = aer_sim.run(rqc_t,shots = 8912)
rresult = rjob.result()
rcounts = rresult.get_counts()
print(rcounts)
plot_histogram(rcounts)
# Out:
# {'00111 00': 2196, '00100 00': 2245, '00110 00': 2240, '00101 00': 2231}

# %% [markdown]
# ### GREEN

# %%
qr3=QuantumRegister(2,'pos')
qr4=QuantumRegister(3,'gpv')
cr1=ClassicalRegister(2)
gqc=QuantumCircuit(qr3,qr4,cr1)
gqc.draw('mpl')

# %%
gqc.h(0)
gqc.h(1)
gqc.i(2)
gqc.i(3)
gqc.barrier()

# %%
gtheta = pi/2

# %%
#pixel 1
gqc.cry(gtheta,0,3)
gqc.cx(0,1)
gqc.cry(gtheta,1,3)
gqc.cx(0,1)
gqc.cry(gtheta,1,3)
gqc.barrier()

# %%
#pixel 2
gqc.x(0)
gqc.cry(gtheta,0,3)
gqc.cx(0,1)
gqc.cry(gtheta,1,3)
gqc.cx(0,1)
gqc.cry(gtheta,1,3)
gqc.barrier()

# %%
#pixel 3
gqc.x(0)
gqc.x(1)
gqc.cry(gtheta,0,3)
gqc.cx(0,1)
gqc.cry(gtheta,1,3)
gqc.cx(0,1)
gqc.cry(gtheta,1,3)
gqc.barrier()

# %%
#pixel 4
gqc.x(0)
gqc.cry(gtheta,0,3)
gqc.cx(0,1)
gqc.cry(gtheta,1,3)
gqc.cx(0,1)
gqc.cry(gtheta,1,3)
gqc.barrier()

# %%
gqc.measure_all()
gqc.draw('mpl')

# %%
aer_sim = Aer.get_backend('aer_simulator')
gqc_t = transpile(gqc,aer_sim)
gjob = aer_sim.run(gqc_t,shots = 8912)
gresult = gjob.result()
gcounts = gresult.get_counts()
print(gcounts)
plot_histogram(gcounts)
# Out:
# {'01000 00': 2202, '01001 00': 2261, '01011 00': 2199, '01010 00': 2250}

# %% [markdown]
# ### BLUE

# %%
qr5 = QuantumRegister(2,'pos')
qr6 = QuantumRegister(3,'bpv') #pv = pixelvalue
cr2 = ClassicalRegister(2)
bqc = QuantumCircuit(qr5,qr6,cr2)
bqc.draw('mpl')

# %%
bqc.h(0)
bqc.h(1)
for k in range(2,5,1):
    bqc.i(k)
bqc.barrier()

# %%
btheta = pi/2

# %%
#pixel 1
bqc.cry(btheta,0,4)
bqc.cx(0,1)
bqc.cry(btheta,1,4)
bqc.cx(0,1)
bqc.cry(btheta,1,4)
bqc.barrier()

# %%
#pixel 2
bqc.x(0)
bqc.cry(btheta,0,4)
bqc.cx(0,1)
bqc.cry(btheta,1,4)
bqc.cx(0,1)
bqc.cry(btheta,1,4)
bqc.barrier()

# %%
#pixel 3
bqc.x(0)
bqc.x(1)
bqc.cry(btheta,0,4)
bqc.cx(0,1)
bqc.cry(btheta,1,4)
bqc.cx(0,1)
bqc.cry(btheta,1,4)
bqc.barrier()

# %%
#pixel 4
bqc.x(0)
bqc.cry(btheta,0,4)
bqc.cx(0,1)
bqc.cry(btheta,1,4)
bqc.cx(0,1)
bqc.cry(btheta,1,4)

# %%
bqc.measure_all()
bqc.draw('mpl')

# %%
aer_sim = Aer.get_backend('aer_simulator')
bqc_t = transpile(bqc,aer_sim)
bjob = aer_sim.run(bqc_t,shots = 8912)
bresult = bjob.result()
bcounts = bresult.get_counts()
print(bcounts)
plot_histogram(bcounts)
# Out:
# {'10000 00': 2274, '10010 00': 2221, '10011 00': 2135, '10001 00': 2282}
